# %%
import numpy as np
import pandas as pd
from DataSetting import *
from Regressor import * 
from HelpFunctions import *
from DefineModels import * 



## Read Data
AutoTrain = pd.read_csv("datasets/AutoTrain.csv", na_values="?")
BikeTrain = pd.read_csv("datasets/BikeTrain.csv")
Facebook = pd.read_csv("datasets/Facebook.csv", header = None)
RealEstate = pd.read_csv("datasets/RealEstate.csv")




## EVALUATE AUTO TRAIN
AutoTrain.horsepower = AutoTrain.horsepower.fillna(AutoTrain.horsepower.mean())

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
AutoTrain.head()
# Out:
#     id   mpg                 carName  cylinders  displacement  horsepower  \
# 0   37  19.0         ford torino 500          6         250.0        88.0
# 1  312  32.1      chevrolet chevette          4          98.0        70.0
# 2   29   9.0                hi 1200d          8         304.0       193.0
# 3  330  44.6     honda civic 1500 gl          4          91.0        67.0
# 4   71  13.0  chrysler newport royal          8         400.0       190.0
#
#    weight  acceleration  modelYear  origin
# 0    3302          15.5         71       1
# 1    2120          15.5         80       1
# 2    4732          18.5         70       1
# 3    1850          13.8         80       3
# 4    4422          12.5         72       1

# %%
sns.pairplot(AutoTrain[["mpg", "displacement", "horsepower", "weight", "acceleration", "modelYear"]])

# %%
f, axes = plt.subplots(1, 2, figsize=(18, 8), dpi= 80, facecolor='w', edgecolor='k')

sns.boxplot(x="cylinders", y="mpg", data=AutoTrain , ax=axes[0])
sns.boxplot(x="origin", y="mpg", data=AutoTrain , ax=axes[1])

# %%
i = ""
[i += j for j in AutoTrain.columns]
# Out:
# Index(['id', 'mpg', 'carName', 'cylinders', 'displacement', 'horsepower',
#        'weight', 'acceleration', 'modelYear', 'origin'],
#       dtype='object')
